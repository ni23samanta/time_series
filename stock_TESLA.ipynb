# %%
import pandas_datareader as pdr

# %%
import pandas as pd
from datetime import datetime

# %%
df_tesla= pdr.get_data_yahoo('TSLA')
df_tesla
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_tesla= pdr.get_data_yahoo('TSLA')
#       2 df_tesla
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
#import yfinance as yf

# Download TSLA stock data
#tsla_df = yf.download("TSLA", start="2017-01-01", end="2022-12-31")

# Save to CSV
#tsla_df.to_csv("tesla_stock_2017_2022.csv")

#print("Tesla stock data saved to 'tesla_stock_2017_2022.csv")

# %%
import pandas as pd
df_tesla = pd.read_csv("C:/Users/user/Downloads/Tesla.csv")

# %%
df_tesla
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
# Convert the 'Date' column to datetime format for accurate plotting
df_tesla['Date'] = pd.to_datetime(df_tesla['Date'])

# Plot Open price over time
plt.figure(figsize=(12, 6))
plt.plot(df_tesla['Date'], df_tesla['Open'], color='teal', label='Open Price')
plt.title('Tesla Open Price Over Time')
plt.xlabel('Date')
plt.ylabel('Open Price (USD)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_tesla['Open:10 days rolling'] = df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla['Open:30 days rolling'] = df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla['Open:50 days rolling'] = df_tesla['Open'].rolling(window=50,min_periods=1).mean()

# %%
# Plotting
plt.figure(figsize=(14, 7))
plt.plot(df_filtered['Date'], df_filtered['Open'], label='Open Price', color='blue')
plt.plot(df_filtered['Date'], df_filtered['Open:10 days rolling'], label='10-Day Rolling Avg', color='orange')
plt.plot(df_filtered['Date'], df_filtered['Open:30 days rolling'], label='30-Day Rolling Avg', color='green')
plt.plot(df_filtered['Date'], df_filtered['Open:50 days rolling'], label='50-Day Rolling Avg', color='red')

plt.title('Tesla Open Price with 10, 30, 50-Day Rolling Averages (2015-2016)')
plt.xlabel('Date')
plt.ylabel('Open Price (USD)')
plt.legend()
plt.tight_layout()
plt.show()
